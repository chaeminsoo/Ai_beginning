# %%
# 파이썬 ≥3.5 필수
import sys
assert sys.version_info >= (3, 5)

# 사이킷런 ≥0.20 필수
import sklearn
assert sklearn.__version__ >= "0.20"

# 공통 모듈 임포트
import numpy as np
import os

# 노트북 실행 결과를 동일하게 유지하기 위해
np.random.seed(42)

# 깔끔한 그래프 출력을 위해
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# 그림을 저장할 위치
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "training_linear_models"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("그림 저장:", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import numpy as np

X = 2*np.random.rand(100,1)
y = 4+ 3*X +np.random.randn(100,1)

# %%
plt.plot(X,y,'b.')

# %%
ones = np.ones((100,1))

# %%
# np.concatenate([ones,X], axis=1)
X_b = np.c_[ones,X]

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([4.21509616]), array([[2.77011339]]))

# %%
X_b[10:11]
# Out:
# array([[1.        , 0.04116899]])

# %%
import numpy as np
m = 100
ta = 3
tb = 4
tr = 8
th = np.random.rand(m, 1) * 2 * np.pi
x = tr * np.cos(th) + ta + np.random.randn(m, 1)
y = tr * np.sin(th) + tb + np.random.randn(m, 1)


plt.plot(x, y, 'b.')

# %%
X = np.c_[-2*x, -2*y, np.ones((m, 1))]
Y = -(x**2) -(y**2)
result, _, _, _ = np.linalg.lstsq(X, Y, None)
ma, mb, mc = result
mr = (ma**2 + mb**2 - mc) ** 0.5
ma, mb, mr
# Out:
# (array([3.10278524]), array([3.97112244]), array([8.08019508]))

# %%
th = np.linspace(0, 2 * np.pi, 100)
mx = mr * np.cos(th) + ma
my = mr * np.sin(th) + mb
plt.plot(mx, my, 'r-')
plt.plot(x, y, 'b.')

tx = tr * np.cos(th) + ta
ty = tr * np.sin(th) + tb
plt.plot(tx, ty, 'b-')
